# %% [markdown]
# ### Ingesting sprints file

# %%
# %run ../00-common/1.environment_config

# %%
# %run ../00-common/2.bronze_helpers

# %%
dbutils.widgets.text("p_batch_id", "")  
v_batch_id = dbutils.widgets.get("p_batch_id")

# %%
source_folder = f'{landing_folder_path}/{v_batch_id}/sprints'
table_name = f'{catalog_name}.{bronze_schema}.sprints'

# %%
# Schema Validation
from pyspark.sql.types import StructField, StructType, StringType, FloatType, IntegerType

sprints_schema = StructType([
    StructField("date", StringType()),
    StructField("raceName", StringType()),
    StructField("round", IntegerType()),
    StructField("season", IntegerType()),
    StructField("url", StringType()),
    StructField("constructorId", StringType()),
    StructField("driverId", StringType()),
    StructField("grid", IntegerType()),
    StructField("laps", IntegerType()),
    StructField("number", IntegerType()),
    StructField("points", FloatType()),
    StructField("position", IntegerType()),
    StructField("positionText", StringType()),
    StructField("status", StringType())

])

# %%
sprints_df = (
    spark.read
    .format('json')
    .option('mode','FAILFAST')
    .option('multiLine',True) # multiline json file
    .schema(sprints_schema) 
    .load(source_folder)
)

# %%
display(sprints_df)

# %%
# Ingesting metadata
sprints_df_final = add_file_metadata(sprints_df)

# %%
display(sprints_df_final)

# %%
write_to_bronze(sprints_df_final, table_name, v_batch_id)

# %%
display(spark.table(table_name))
